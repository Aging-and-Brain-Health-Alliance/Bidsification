# %%
import os
import shutil
import zipfile
import bidsme
import datetime
import pandas as pd
# from GluckLab.utils import subjectid_to_seqid as s2s
from multiprocessing import Pool

# %%
# resources directory
resources_dir = "resources"

# data directory
data_dir = "data"

# stages directory names
# Change paths/names to your liking
# For paths use os.path.join("path", "to", "your", "directory"). 
# This will generate a path like path/to/your/directory in an approtiate format for your OS
compressed_dir = os.path.join(data_dir, "compressed")
extract_dir = os.path.join(data_dir, "extracted")
reorganize_dir = os.path.join(data_dir, "reorganized")
prepared_dir = os.path.join(data_dir, "prepared")
bidsified_dir =  os.path.join(data_dir, "bidsified")

# bidsmap path
bidsmap_path = os.path.join(resources_dir, "bidsmap.yaml")

# logs
logs_dir = "logs"
extraction_log_name = "extraction_log.csv"
extraction_log_path = os.path.join(logs_dir, extraction_log_name)

reorganization_log_name = "reorganization_log.csv"
reorganization_log_path = os.path.join(logs_dir, reorganization_log_name)

bidsify_bval_bvec_log_name = "bidsify_bval_bvec_log.csv"
bidsify_bval_bvec_log_path = os.path.join(logs_dir, bidsify_bval_bvec_log_name)

# Multiprocessing
# number of subprocesses to divide the reorganization process among all CPU cores
# In this case 4 subprocesses per CPU core 
number_of_subprocesses = os.cpu_count() * 4


# Exercise Subject IDs
exercise_subjectids_path = os.path.join(resources_dir, "exercise_subjectids.csv")
exercise_subjectids = pd.read_csv(exercise_subjectids_path).dropna(subset=["alias_exercise"], how="any")
exercise_first_session = exercise_subjectids.groupby("alias_exercise").first().reset_index()
exercise_second_session = exercise_subjectids.groupby("alias_exercise").last().reset_index()

# %%
dirs_to_create = [extract_dir, reorganize_dir, prepared_dir, bidsified_dir, logs_dir]
for dir in dirs_to_create:
    os.makedirs(dir, exist_ok=True)

# %%
# compressed NIfTI data dirs
zipfiles = os.listdir(compressed_dir)
zipfiles_paths = [os.path.join(compressed_dir, file) for file in zipfiles]

# %%
def extract(filepath: str, extract_dir: str) -> dict:
    """
    Extracts a zip file (`filepath`) to `extract_dir` and returns a log entry specifying the success or failure of the extraction.

    Args:
        - filepath: path to a zip file.
        - extract_dir: directory to extract the zip file to.
    
    Returns:
        - log_entry: dictionary specifying the success or failure of the extraction.

    """
    filename = os.path.basename(filepath)
    now = datetime.datetime.now()
    log_entry = {"filename": filename, 
                 "extraction_date": now.date(),
                 "extraction_time" : now.time(),
    }

    try:
        with zipfile.ZipFile(filepath, "r") as zip_ref:

            zip_ref.extractall(extract_dir)
            log_entry["extraction_status"] = "success"
            log_entry["error"] = None

    except Exception as error:
        log_entry["extraction_status"] = "fail"
        log_entry["error"] = error

    return log_entry

# %%
prev_extraction_log = None
extraction_log = []
files_to_extract = []

if not os.path.isfile(extraction_log_path):
    # extract all the zipfiles
    files_to_extract = zipfiles_paths

else:
    # read the previous log
    prev_extraction_log = pd.read_csv(extraction_log_path)

    # get the files that have been extracted already
    extracted_files = set(prev_extraction_log["filename"])

    # extract only the zipfiles that have not been extracted yet
    files_to_extract = [filepath for filepath in zipfiles_paths if os.path.basename(filepath) not in extracted_files]

with Pool(number_of_subprocesses) as p:
    extract_args = [(file, extract_dir) for file in files_to_extract]
    extraction_log = p.starmap(extract, extract_args)

if isinstance(prev_extraction_log, pd.DataFrame):
    extraction_log = pd.concat([prev_extraction_log, pd.DataFrame(extraction_log)], ignore_index=True)
else:
    extraction_log = pd.DataFrame(extraction_log)

extraction_log.to_csv(extraction_log_path, index=False)
extraction_log
# Out:
#           filename extraction_date  extraction_time extraction_status  \
# 0      AAL_039.zip      2025-01-13  17:01:10.819065              fail
# 1       COV249.zip      2025-01-13  17:01:10.819158           success
# 2       COV101.zip      2025-01-13  17:01:10.819191              fail
# 3       AA_248.zip      2025-01-13  17:01:10.819274              fail
# 4      AA_R319.zip      2025-01-13  17:01:10.819368           success
# ..             ...             ...              ...               ...
# 426  AA_R261_L.zip      2025-01-13  17:05:46.067285           success
# 427     AA_287.zip      2025-01-13  17:05:47.037325           success
# 428  AA_R461_0.zip      2025-01-13  17:05:48.750397           success
# 429    AA_R345.zip      2025-01-13  17:05:48.782784           success
# 430     COV047.zip      2025-01-13  17:05:51.663987           success
#
#                                 error
# 0    Bad magic number for file header
# 1                                None
# 2              File is not a zip file
# 3    Bad magic number for file header
# 4                                None
# ..                                ...
# 426                              None
# 427                              None
# 428                              None
# 429                              None
# 430                              None
#
# [431 rows x 5 columns]

# %%
def dir_to_subjectid(dirname: str):
    '''
    Takes a dirname and attempts to translate it to a Subject ID as best as possible.
    '''
    # Subject ID must be the name of its directory, with 
    # all characters capitalized,
    subjectid = dirname.upper()

    # Delete "_O", "_0", "_Q", "_FMRI" and/or "FMRI" from the Subject ID
    subjectid = subjectid.replace("_O", "")
    subjectid = subjectid.replace("_Q", "")
    subjectid = subjectid.replace("_FMRI", "")
    subjectid = subjectid.replace("FMRI", "")

    # Correct common naming mistake COVR### instead of COV_R###
    subjectid  = subjectid.replace("COVR", "COV_R")

    # This if is necessary to not mess up subject IDs like AA_0##_L
    if subjectid.endswith("_0"):
        subjectid = subjectid.replace("_0", "")

    # Correct invalid subject IDs in the form AA_###, without affecting valid Subject IDs in the forms AA_R### or AA_###_L
    if subjectid.startswith("AA_") and subjectid[3] != "R" and subjectid[-1] != "L":
        subjectid = subjectid.replace("_", "")

    if subjectid.startswith("__COV") or subjectid.startswith("__A"):
        subjectid = subjectid[2:]

    # Exercise ID translation
    if subjectid.startswith("EX"):
        row = None
        # Dirname is like EX###_[SUBJECTID], but the subjectid might be misspelled so lets take it from the table instead
        if "_" in subjectid:
            subjectid = subjectid.split("_")[0]
            row = exercise_second_session.loc[exercise_second_session["alias_exercise"] == subjectid]["subjectid"]
        # Dirname is just EX###
        else:
            row = exercise_first_session.loc[exercise_first_session["alias_exercise"] == subjectid]["subjectid"]

        if not row.empty:
            subjectid = row.values[0]
        
    return subjectid
    

def reorganize(dirpath: str, reorganize_dir: str) -> dict:
    '''
    Reorganizes a single directory in the from a structure like:

    <Data_directory>
    ├── <SubjectID for first session>
    |   ├── example-1.json
    |   └── example-1.nii.gz

    To a structure like:

    <Data directory>
    ├── <SeqID>
    |   ├── session-01
    |   |   ├── example-1.json
    |   |   └── example-1.nii.gz

    Args:
        - dirpath: path to subject directory to reorganize.
        - reorganize_dir: directory where to put the reorganized subject directory.

    Returns:
        - log_entry: dictionary specifying the success or failure of the reorganization.
    '''
    dirname = os.path.basename(dirpath)
    subjectid = dir_to_subjectid(dirname)

    session = s2s.get_instance_number(subjectid)
    seqid = s2s.get_seqid(subjectid)

    now = datetime.datetime.now()
    log_entry = {"directory": dirname,
                 "subjectid": subjectid,
                 "seqid": seqid,
                 "session": session,
                 "reorganization_date": now.date(),
                 "reorganization_time": now.time()
                 }
    if seqid == None or session == None:
        log_entry["reorganization_status"] = "fail"
        log_entry["error"] = "Directory name translated to an invalid SubjectID"
    else:
        try:
            # Path to target reorganized directory <extract_dir>/sub-<seqid>/ses-0<session number>
            target_dir = os.path.join(reorganize_dir, f"sub-{seqid}", f"ses-0{session}")
            
            # Move all files from extracted directory to reorganized directory
            shutil.move(dirpath, target_dir)

            log_entry["reorganization_status"] = "success"
            log_entry["error"] = None
    
        except Exception as error:
            log_entry["reorganization_status"] = "fail"
            log_entry["error"] = error
    return log_entry

# %%
prev_reorganization_log = None
reorganization_log = []
dirs_to_reorganize = []
subjects = []

if not os.path.isfile(reorganization_log_path):

    # reorganize all the directories extracted
    dirs_to_reorganize = [os.path.join(extract_dir, dirname) for dirname in os.listdir(extract_dir)]
else:
    
    # read the previous log
    prev_reorganization_log = pd.read_csv(reorganization_log_path)

    # get the directories that have been reorganized already
    reorganized_files = set(prev_reorganization_log["directory"])
    # extract only the zipfiles that have not been extracted yet
    dirs_to_reorganize = [os.path.join(extract_dir, dirname) for dirname in os.listdir(extract_dir) if dirname not in reorganized_files]
    # remove the extraction log from the list
    dirs_to_reorganize = [dir for dir in dirs_to_reorganize if dirs_to_reorganize != extraction_log_path]

with Pool(number_of_subprocesses) as p:
    reorganize_args = [(dir, reorganize_dir) for dir in dirs_to_reorganize]
    reorganization_log = p.starmap(reorganize, reorganize_args)

if isinstance(prev_reorganization_log, pd.DataFrame):
    reorganization_log = pd.concat([prev_reorganization_log, pd.DataFrame(reorganization_log)], ignore_index=True)
else:
    reorganization_log = pd.DataFrame(reorganization_log)

reorganization_log.to_csv(reorganization_log_path, index=False)
reorganization_log
# Out:
#       directory   subjectid seqid  session reorganization_date  \
# 0         EX022  AA_3R317_L  A317      4.0          2025-01-13
# 1        COV210      COV210  C210      1.0          2025-01-13
# 2         AA445       AA445  A445      1.0          2025-01-13
# 3        Cov144      COV144  C144      1.0          2025-01-13
# 4         AA416       AA416  A416      1.0          2025-01-13
# ..          ...         ...   ...      ...                 ...
# 441    AA_413_Q       AA413  A413      1.0          2025-01-13
# 442   AA_R461_0     AA_R461  A461      2.0          2025-01-13
# 443      Cov094      COV094  C094      1.0          2025-01-13
# 444      AA_255       AA255  A255      1.0          2025-01-13
# 445  AA_5R205_L  AA_5R205_L  A205      6.0          2025-01-13
#
#     reorganization_time reorganization_status error
# 0       17:09:38.517573               success  None
# 1       17:09:38.515645               success  None
# 2       17:09:38.515394               success  None
# 3       17:09:38.515963               success  None
# 4       17:09:38.515820               success  None
# ..                  ...                   ...   ...
# 441     17:11:33.865116               success  None
# 442     17:11:33.868260               success  None
# 443     17:11:33.868334               success  None
# 444     17:11:33.868410               success  None
# 445     17:11:33.868467               success  None
#
# [446 rows x 8 columns]

# %%
logger = bidsme.init()
if not os.path.isdir(prepared_dir):
    os.makedirs(prepared_dir)
bidsme.prepare(reorganize_dir, prepared_dir)
# Out:
# main(81) - INFO
# main(82) - INFO -------------- START bidsme ----------------
# main(83) - INFO Mon Jan 13 17:15:36 2025
# main(84) - INFO version: 1.8.1
# bidsme.schema.BIDSschema(670) - INFO Loaded BIDS schema version 1.10.0
# bidsme.prepare(192) - INFO -------------- Prepearing data -------------
# bidsme.prepare(193) - INFO Source directory: reorganized
# bidsme.prepare(194) - INFO Destination directory: prepared
# bidsme.bidsMeta.BidsTable(141) - INFO Created empty participants.tsv table
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A041/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A041', ses 'ses-01' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A044/ses-03
# bidsme.prepare(58) - INFO Processing: sub 'sub-A044', ses 'ses-03' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A046/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A046', ses 'ses-02' (3 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A079/ses-03
# bidsme.prepare(58) - INFO Processing: sub 'sub-A079', ses 'ses-03' (2 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A085/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A085', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A085/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A085', ses 'ses-02' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A086/ses-05
# bidsme.prepare(58) - INFO Processing: sub 'sub-A086', ses 'ses-05' (37 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A088/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A088', ses 'ses-01' (14 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A091/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A091', ses 'ses-01' (16 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A091/ses-03
# bidsme.prepare(58) - INFO Processing: sub 'sub-A091', ses 'ses-03' (2 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A094/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A094', ses 'ses-01' (11 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A096/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A096', ses 'ses-01' (11 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A100/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A100', ses 'ses-01' (18 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A101/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A101', ses 'ses-01' (11 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A103/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A103', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A103/ses-03
# bidsme.prepare(58) - INFO Processing: sub 'sub-A103', ses 'ses-03' (2 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A104/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A104', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A111/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A111', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A111/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A111', ses 'ses-02' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A117/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A117', ses 'ses-01' (18 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A117/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A117', ses 'ses-02' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A119/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A119', ses 'ses-01' (24 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A120/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A120', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A125/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A125', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A125/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A125', ses 'ses-02' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A129/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A129', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A135/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A135', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A141/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A141', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A141/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A141', ses 'ses-02' (28 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A141/ses-03
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A141/ses-03
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A141/ses-04
# bidsme.prepare(58) - INFO Processing: sub 'sub-A141', ses 'ses-04' (3 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A142/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A142', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A143/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A143', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A143/ses-05
# bidsme.prepare(58) - INFO Processing: sub 'sub-A143', ses 'ses-05' (35 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A146/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A146', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A146/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A146', ses 'ses-02' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A152/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A152', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A152/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A152', ses 'ses-02' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A152/ses-03
# bidsme.prepare(58) - INFO Processing: sub 'sub-A152', ses 'ses-03' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A154/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A154', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A155/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A155', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A155/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A155', ses 'ses-02' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A156/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A156/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A164/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A164', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A165/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A165', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A165/ses-03
# bidsme.prepare(58) - INFO Processing: sub 'sub-A165', ses 'ses-03' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A172/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A172', ses 'ses-01' (11 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A172/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A172', ses 'ses-02' (14 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A173/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A173', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A173/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A173', ses 'ses-02' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A173/ses-03
# bidsme.prepare(58) - INFO Processing: sub 'sub-A173', ses 'ses-03' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A173/ses-04
# bidsme.prepare(58) - INFO Processing: sub 'sub-A173', ses 'ses-04' (3 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A174/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A174/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A174/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A174', ses 'ses-02' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A174/ses-03
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A174/ses-03
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A174/ses-04
# bidsme.prepare(58) - INFO Processing: sub 'sub-A174', ses 'ses-04' (3 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A176/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A176', ses 'ses-01' (17 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A176/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A176', ses 'ses-02' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A176/ses-04
# bidsme.prepare(58) - INFO Processing: sub 'sub-A176', ses 'ses-04' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A177/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A177', ses 'ses-01' (11 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A177/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A177', ses 'ses-02' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A178/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A178', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A178/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A178', ses 'ses-02' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A179/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A179', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A179/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A179', ses 'ses-02' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A180/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A180/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A181/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A181', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A182/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A182', ses 'ses-01' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A182/ses-03
# bidsme.prepare(58) - INFO Processing: sub 'sub-A182', ses 'ses-03' (9 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A184/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A184', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A187/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A187', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A187/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A187', ses 'ses-02' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A188/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A188', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A188/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A188', ses 'ses-02' (17 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A188/ses-03
# bidsme.prepare(58) - INFO Processing: sub 'sub-A188', ses 'ses-03' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A189/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A189', ses 'ses-02' (30 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A191/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A191/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A196/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A196', ses 'ses-01' (5 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A197/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A197', ses 'ses-01' (5 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A197/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A197', ses 'ses-02' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A203/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A203/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A203/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A203', ses 'ses-02' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A205/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A205/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A205/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A205', ses 'ses-02' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A205/ses-04
# bidsme.prepare(58) - INFO Processing: sub 'sub-A205', ses 'ses-04' (4 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A205/ses-05
# bidsme.prepare(58) - INFO Processing: sub 'sub-A205', ses 'ses-05' (8 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A205/ses-06
# bidsme.prepare(58) - INFO Processing: sub 'sub-A205', ses 'ses-06' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A208/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A208/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A209/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A209/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A220/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A220', ses 'ses-01' (5 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A220/ses-02
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A220/ses-02
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A225/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A225/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A225/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A225', ses 'ses-02' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A228/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A228/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A228/ses-03
# bidsme.prepare(58) - INFO Processing: sub 'sub-A228', ses 'ses-03' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A228/ses-04
# bidsme.prepare(58) - INFO Processing: sub 'sub-A228', ses 'ses-04' (4 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A238/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A238/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A238/ses-02
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A238/ses-02
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A246/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A246/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A246/ses-03
# bidsme.prepare(58) - INFO Processing: sub 'sub-A246', ses 'ses-03' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A246/ses-05
# bidsme.prepare(58) - INFO Processing: sub 'sub-A246', ses 'ses-05' (11 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A248/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A248/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A248/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A248', ses 'ses-02' (11 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A248/ses-03
# bidsme.prepare(58) - INFO Processing: sub 'sub-A248', ses 'ses-03' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A248/ses-05
# bidsme.Modules.base(1002) - WARNING MRI/jsonNIFTI: Ignoring hidden file: .DS_Store
# bidsme.prepare(58) - INFO Processing: sub 'sub-A248', ses 'ses-05' (38 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A255/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A255', ses 'ses-01' (14 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A255/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A255', ses 'ses-02' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A256/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A256', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A259/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A259', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A259/ses-03
# bidsme.prepare(58) - INFO Processing: sub 'sub-A259', ses 'ses-03' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A259/ses-04
# bidsme.prepare(58) - INFO Processing: sub 'sub-A259', ses 'ses-04' (3 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A261/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A261/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A261/ses-03
# bidsme.prepare(58) - INFO Processing: sub 'sub-A261', ses 'ses-03' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A263/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A263/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A266/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A266/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A267/ses-05
# bidsme.prepare(58) - INFO Processing: sub 'sub-A267', ses 'ses-05' (35 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A273/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A273/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A273/ses-03
# bidsme.prepare(58) - INFO Processing: sub 'sub-A273', ses 'ses-03' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A278/ses-03
# bidsme.prepare(58) - INFO Processing: sub 'sub-A278', ses 'ses-03' (12 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A280/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A280/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A284/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A284/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A285/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A285', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A287/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A287', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A287/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A287', ses 'ses-02' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A287/ses-03
# bidsme.prepare(58) - INFO Processing: sub 'sub-A287', ses 'ses-03' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A287/ses-05
# bidsme.prepare(58) - INFO Processing: sub 'sub-A287', ses 'ses-05' (8 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A288/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A288', ses 'ses-01' (14 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A293/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A293', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A293/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A293', ses 'ses-02' (10 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A293/ses-03
# bidsme.prepare(58) - INFO Processing: sub 'sub-A293', ses 'ses-03' (3 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A293/ses-04
# bidsme.prepare(58) - INFO Processing: sub 'sub-A293', ses 'ses-04' (3 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A296/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A296/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A306/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A306', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A306/ses-03
# bidsme.prepare(58) - INFO Processing: sub 'sub-A306', ses 'ses-03' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A308/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A308', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A309/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A309', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A314/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A314', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A314/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A314', ses 'ses-02' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A315/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A315', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A317/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A317', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A317/ses-04
# bidsme.prepare(58) - INFO Processing: sub 'sub-A317', ses 'ses-04' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A319/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A319', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A319/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A319', ses 'ses-02' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A320/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A320', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A322/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A322', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A322/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A322', ses 'ses-02' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A333/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A333', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A333/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A333', ses 'ses-02' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A336/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A336/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A340/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A340', ses 'ses-01' (17 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A340/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A340', ses 'ses-02' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A341/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A341', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A343/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A343', ses 'ses-01' (14 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A344/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A344', ses 'ses-01' (11 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A345/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A345', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A345/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A345', ses 'ses-02' (19 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A348/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A348', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A355/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A355', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A355/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A355', ses 'ses-02' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A356/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A356', ses 'ses-01' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A356/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A356', ses 'ses-02' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A356/ses-03
# bidsme.prepare(58) - INFO Processing: sub 'sub-A356', ses 'ses-03' (51 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A359/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A359', ses 'ses-01' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A359/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A359', ses 'ses-02' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A359/ses-03
# bidsme.prepare(58) - INFO Processing: sub 'sub-A359', ses 'ses-03' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A361/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A361', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A367/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A367', ses 'ses-01' (17 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A373/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A373', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A374/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A374', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A382/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A382', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A382/ses-02
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A382/ses-02
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A385/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A385', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A385/ses-03
# bidsme.prepare(58) - INFO Processing: sub 'sub-A385', ses 'ses-03' (2 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A392/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A392', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A392/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A392', ses 'ses-02' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A394/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A394', ses 'ses-01' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A398/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A398/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A399/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A399', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A401/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A401', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A407/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A407', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A408/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A408', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A408/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A408', ses 'ses-02' (14 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A413/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A413', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A416/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A416', ses 'ses-01' (3 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A416/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A416', ses 'ses-02' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A416/ses-03
# bidsme.prepare(58) - INFO Processing: sub 'sub-A416', ses 'ses-03' (3 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A417/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A417', ses 'ses-01' (2 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A417/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A417', ses 'ses-02' (10 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A419/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A419', ses 'ses-01' (26 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A425/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A425/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A425/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A425', ses 'ses-02' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A426/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A426/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A426/ses-02
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A426/ses-02
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A427/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A427/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A427/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A427', ses 'ses-02' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A429/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A429', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A429/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A429', ses 'ses-02' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A429/ses-03
# bidsme.prepare(58) - INFO Processing: sub 'sub-A429', ses 'ses-03' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A429/ses-04
# bidsme.prepare(58) - INFO Processing: sub 'sub-A429', ses 'ses-04' (36 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A430/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A430', ses 'ses-01' (4 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A433/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A433', ses 'ses-01' (2 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A436/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A436', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A437/ses-03
# bidsme.prepare(58) - INFO Processing: sub 'sub-A437', ses 'ses-03' (4 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A442/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A442', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A445/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A445/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A457/ses-04
# bidsme.prepare(58) - INFO Processing: sub 'sub-A457', ses 'ses-04' (12 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A460/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A460', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A460/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A460', ses 'ses-02' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A460/ses-03
# bidsme.prepare(58) - INFO Processing: sub 'sub-A460', ses 'ses-03' (3 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A461/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A461/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A461/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-A461', ses 'ses-02' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A468/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-A468/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A471/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A471', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A473/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A473', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A481/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A481', ses 'ses-01' (5 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A486/ses-04
# bidsme.prepare(58) - INFO Processing: sub 'sub-A486', ses 'ses-04' (8 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A491/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A491', ses 'ses-01' (14 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A494/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A494', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A498/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-A498', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-A503/ses-04
# bidsme.Modules.base(1002) - WARNING MRI/jsonNIFTI: Ignoring hidden file: .DS_Store
# bidsme.prepare(58) - INFO Processing: sub 'sub-A503', ses 'ses-04' (35 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C001/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C001', ses 'ses-01' (3 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C001/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-C001', ses 'ses-02' (37 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C002/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C002', ses 'ses-01' (4 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C003/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C003', ses 'ses-01' (3 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C005/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C005', ses 'ses-01' (3 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C006/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C006', ses 'ses-01' (4 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C006/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-C006', ses 'ses-02' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C008/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C008', ses 'ses-01' (3 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C010/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C010', ses 'ses-01' (3 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C011/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C011', ses 'ses-01' (3 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C012/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-C012/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C013/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C013', ses 'ses-01' (3 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C014/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C014', ses 'ses-01' (3 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C015/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C015', ses 'ses-01' (3 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C018/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C018', ses 'ses-01' (3 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C021/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C021', ses 'ses-01' (2 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C022/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-C022', ses 'ses-02' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C028/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-C028/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C028/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-C028', ses 'ses-02' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C031/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C031', ses 'ses-01' (2 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C037/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C037', ses 'ses-01' (2 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C041/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C041', ses 'ses-01' (2 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C042/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C042', ses 'ses-01' (2 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C043/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C043', ses 'ses-01' (2 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C043/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-C043', ses 'ses-02' (37 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C044/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C044', ses 'ses-01' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C045/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C045', ses 'ses-01' (2 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C046/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C046', ses 'ses-01' (2 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C046/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-C046', ses 'ses-02' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C047/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C047', ses 'ses-01' (2 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C048/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C048', ses 'ses-01' (2 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C074/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C074', ses 'ses-01' (4 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C075/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C075', ses 'ses-01' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C075/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-C075', ses 'ses-02' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C076/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C076', ses 'ses-01' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C081/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C081', ses 'ses-01' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C085/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C085', ses 'ses-01' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C094/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-C094/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C094/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-C094', ses 'ses-02' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C099/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-C099/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C102/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C102', ses 'ses-01' (8 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C111/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C111', ses 'ses-01' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C114/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C114', ses 'ses-01' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C117/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C117', ses 'ses-01' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C119/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C119', ses 'ses-01' (7 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C121/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C121', ses 'ses-01' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C126/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C126', ses 'ses-01' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C128/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C128', ses 'ses-01' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C129/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C129', ses 'ses-01' (11 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C131/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C131', ses 'ses-01' (37 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C132/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C132', ses 'ses-01' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C135/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C135', ses 'ses-01' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C140/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C140', ses 'ses-01' (37 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C142/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C142', ses 'ses-01' (11 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C144/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C144', ses 'ses-01' (12 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C152/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C152', ses 'ses-01' (8 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C153/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C153', ses 'ses-01' (8 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C158/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C158', ses 'ses-01' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C159/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C159', ses 'ses-01' (11 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C160/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C160', ses 'ses-01' (8 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C161/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C161', ses 'ses-01' (11 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C162/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C162', ses 'ses-01' (11 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C163/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C163', ses 'ses-01' (8 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C165/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-C165/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C174/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C174', ses 'ses-01' (11 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C176/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-C176/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C177/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C177', ses 'ses-01' (32 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C178/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-C178/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C179/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-C179/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C180/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C180', ses 'ses-01' (10 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C182/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C182', ses 'ses-01' (35 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C185/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-C185/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C201/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C201', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C203/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C203', ses 'ses-01' (37 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C204/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C204', ses 'ses-01' (37 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C210/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C210', ses 'ses-01' (35 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C211/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C211', ses 'ses-01' (35 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C213/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C213', ses 'ses-01' (37 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C215/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C215', ses 'ses-01' (17 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C218/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C218', ses 'ses-01' (37 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C219/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C219', ses 'ses-01' (37 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C223/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C223', ses 'ses-01' (35 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C224/ses-01
# bidsme.Modules.base(1002) - WARNING MRI/jsonNIFTI: Ignoring hidden file: .DS_Store
# bidsme.prepare(58) - INFO Processing: sub 'sub-C224', ses 'ses-01' (35 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C225/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C225', ses 'ses-01' (35 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C227/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C227', ses 'ses-01' (37 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C230/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C230', ses 'ses-01' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C232/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C232', ses 'ses-01' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C233/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C233', ses 'ses-01' (11 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C235/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C235', ses 'ses-01' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C236/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C236', ses 'ses-01' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C239/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C239', ses 'ses-01' (37 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C240/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C240', ses 'ses-01' (37 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C242/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C242', ses 'ses-01' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C245/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C245', ses 'ses-01' (37 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C248/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C248', ses 'ses-01' (37 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C249/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C249', ses 'ses-01' (37 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C252/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C252', ses 'ses-01' (37 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C255/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C255', ses 'ses-01' (37 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C256/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C256', ses 'ses-01' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C263/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C263', ses 'ses-01' (37 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C267/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C267', ses 'ses-01' (37 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C269/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C269', ses 'ses-01' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C270/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C270', ses 'ses-01' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C273/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C273', ses 'ses-01' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C278/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C278', ses 'ses-01' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C281/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C281', ses 'ses-01' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C290/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C290', ses 'ses-01' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C291/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C291', ses 'ses-01' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C293/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C293', ses 'ses-01' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C298/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C298', ses 'ses-01' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C299/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C299', ses 'ses-01' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C303/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C303', ses 'ses-01' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C305/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C305', ses 'ses-01' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C308/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C308', ses 'ses-01' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C313/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C313', ses 'ses-01' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C320/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C320', ses 'ses-01' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C321/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C321', ses 'ses-01' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C327/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C327', ses 'ses-01' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C332/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C332', ses 'ses-01' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C335/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C335', ses 'ses-01' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C349/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C349', ses 'ses-01' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-C350/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-C350', ses 'ses-01' (40 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L002/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-L002', ses 'ses-01' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L002/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-L002', ses 'ses-02' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L012/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-L012', ses 'ses-01' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L014/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-L014', ses 'ses-01' (12 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L015/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-L015', ses 'ses-01' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L015/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-L015', ses 'ses-02' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L022/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-L022', ses 'ses-01' (15 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L022/ses-03
# bidsme.prepare(58) - INFO Processing: sub 'sub-L022', ses 'ses-03' (11 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L023/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-L023', ses 'ses-01' (5 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L024/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-L024', ses 'ses-01' (4 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L024/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-L024', ses 'ses-02' (3 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L029/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-L029', ses 'ses-01' (4 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L029/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-L029', ses 'ses-02' (3 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L029/ses-03
# bidsme.prepare(58) - INFO Processing: sub 'sub-L029', ses 'ses-03' (35 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L030/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-L030/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L032/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-L032', ses 'ses-01' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L034/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-L034/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L035/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-L035', ses 'ses-01' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L039/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-L039/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L040/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-L040/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L041/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-L041/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L041/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-L041', ses 'ses-02' (3 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L044/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-L044/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L044/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-L044', ses 'ses-02' (3 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L045/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-L045', ses 'ses-01' (11 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L045/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-L045', ses 'ses-02' (3 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L045/ses-03
# bidsme.Modules.base(1002) - WARNING MRI/jsonNIFTI: Ignoring hidden file: .DS_Store
# bidsme.prepare(58) - INFO Processing: sub 'sub-L045', ses 'ses-03' (38 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L046/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-L046/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L047/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-L047/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L048/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-L048/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L049/ses-01
# bidsme.prepare(338) - WARNING Unable to identify data in folder reorganized/sub-L049/ses-01
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L052/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-L052', ses 'ses-01' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L054/ses-01
# bidsme.prepare(58) - INFO Processing: sub 'sub-L054', ses 'ses-01' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L103/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-L103', ses 'ses-02' (13 files)
# bidsme.prepare(295) - INFO Scanning folder reorganized/sub-L225/ses-02
# bidsme.prepare(58) - INFO Processing: sub 'sub-L225', ses 'ses-02' (13 files)

# %%
bidsme.bidsify(prepared_dir, bidsified_dir, bidsmapfile=bidsmap_path)
# Out:
# bidsme.bidsify(188) - INFO -------------- Prepearing data -------------
# bidsme.bidsify(189) - INFO Source directory: prepared
# bidsme.bidsify(190) - INFO Destination directory: bidsified
# bidsme.bidsify(212) - WARNING Dataset description file 'dataset_description.json' not found in 'bidsified'
# bidsme.bidsify(218) - WARNING Dataset readme file 'README' not found in 'bidsified'
# bidsme.bidsify(233) - INFO loading bidsmap bidsified/code/bidsme/bidsmap.yaml
# bidsme.bidsMeta.BidsTable(134) - INFO Loaded participants.tsv table with 242 entries
# bidsme.bidsMeta.BidsTable(141) - INFO Created empty participants.tsv table
# bidsme.bidsify(344) - INFO sub-A041 (1/242): Scanning folder prepared/sub-A041/ses-01
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A041', ses 'ses-01', 001-localizer/0 (3 files)
# bidsme.bidsify(97) - INFO 001-localizer/0: ignored modality
# bidsme.bidsify(97) - INFO 001-localizer/1: ignored modality
# bidsme.bidsify(97) - INFO 001-localizer/2: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A041', ses 'ses-01', 002-MPRAGE GRAPPA2/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A041', ses 'ses-01', 003-Axial T2-FLAIR/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A041', ses 'ses-01', 004-AXIAL_T2_STAR/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A041', ses 'ses-01', 005-Field_mapping/0 (1 files)
# bidsme.bidsify(97) - INFO 005-Field_mapping/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A041', ses 'ses-01', 006-MB_Resting_SBRef/0 (1 files)
# bidsme.bidsify(97) - INFO 006-MB_Resting_SBRef/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A041', ses 'ses-01', 007-MB_Resting/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A041', ses 'ses-01', 008-ep2d_diff_30_iso/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 008-ep2d_diff_30_iso/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 008-ep2d_diff_30_iso/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A041', ses 'ses-01', 009-ep2d_diff_30_iso_ADC/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 009-ep2d_diff_30_iso_ADC/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 009-ep2d_diff_30_iso_ADC/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A041', ses 'ses-01', 010-ep2d_diff_30_iso_FA/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 010-ep2d_diff_30_iso_FA/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 010-ep2d_diff_30_iso_FA/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A041', ses 'ses-01', 011-ep2d_diff_30_iso_ColFA/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 011-ep2d_diff_30_iso_ColFA/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 011-ep2d_diff_30_iso_ColFA/0 missing bval file for diffusion recording
# bidsme.bidsify(344) - INFO sub-A044 (2/242): Scanning folder prepared/sub-A044/ses-03
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A044', ses 'ses-03', 001-AAHead_Scout/0 (1 files)
# bidsme.bidsify(97) - INFO 001-AAHead_Scout/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A044', ses 'ses-03', 002-AAHead_Scout_MPR_sag/0 (4 files)
# bidsme.bidsify(97) - INFO 002-AAHead_Scout_MPR_sag/0: ignored modality
# bidsme.bidsify(97) - INFO 002-AAHead_Scout_MPR_sag/1: ignored modality
# bidsme.bidsify(97) - INFO 002-AAHead_Scout_MPR_sag/2: ignored modality
# bidsme.bidsify(97) - INFO 002-AAHead_Scout_MPR_sag/3: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A044', ses 'ses-03', 003-AAHead_Scout_MPR_cor/0 (3 files)
# bidsme.bidsify(97) - INFO 003-AAHead_Scout_MPR_cor/0: ignored modality
# bidsme.bidsify(97) - INFO 003-AAHead_Scout_MPR_cor/1: ignored modality
# bidsme.bidsify(97) - INFO 003-AAHead_Scout_MPR_cor/2: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A044', ses 'ses-03', 004-AAHead_Scout_MPR_tra/0 (3 files)
# bidsme.bidsify(97) - INFO 004-AAHead_Scout_MPR_tra/0: ignored modality
# bidsme.bidsify(97) - INFO 004-AAHead_Scout_MPR_tra/1: ignored modality
# bidsme.bidsify(97) - INFO 004-AAHead_Scout_MPR_tra/2: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A044', ses 'ses-03', 005-GF_Map/0 (2 files)
# bidsme.bidsify(97) - INFO 005-GF_Map/0: ignored modality
# bidsme.bidsify(97) - INFO 005-GF_Map/1: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A044', ses 'ses-03', 006-GF_Map/0 (1 files)
# bidsme.bidsify(97) - INFO 006-GF_Map/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A044', ses 'ses-03', 007-MPRage/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A044', ses 'ses-03', 008-Sagittal_3D_FLAIR/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A044', ses 'ses-03', 009-MB_fMRI_resting_state/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A044', ses 'ses-03', 010-AXMB_DTI_AP/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 010-AXMB_DTI_AP/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 010-AXMB_DTI_AP/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A044', ses 'ses-03', 011-AXMB_DTI_PA/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 011-AXMB_DTI_PA/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 011-AXMB_DTI_PA/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A044', ses 'ses-03', 012-Sag_T2w_SPC/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A044', ses 'ses-03', 013-Axial_3D_ME_T2_GRE/0 (5 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A044', ses 'ses-03', 014-Axial_3D_ME_T2_GRE/0 (5 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A044', ses 'ses-03', 015-Axial_ASL_3D_1000/0 (1 files)
# bidsme.bidsify(97) - INFO 015-Axial_ASL_3D_1000/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A044', ses 'ses-03', 016-Perfusion_Weighted/0 (1 files)
# bidsme.bidsify(97) - INFO 016-Perfusion_Weighted/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A044', ses 'ses-03', 017-Axial_ASL_3D_1500/0 (1 files)
# bidsme.bidsify(97) - INFO 017-Axial_ASL_3D_1500/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A044', ses 'ses-03', 018-Perfusion_Weighted/0 (1 files)
# bidsme.bidsify(97) - INFO 018-Perfusion_Weighted/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A044', ses 'ses-03', 019-Axial_ASL_3D_2000/0 (1 files)
# bidsme.bidsify(97) - INFO 019-Axial_ASL_3D_2000/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A044', ses 'ses-03', 020-Perfusion_Weighted/0 (1 files)
# bidsme.bidsify(97) - INFO 020-Perfusion_Weighted/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A044', ses 'ses-03', 021-Axial_ASL_3D_2510/0 (1 files)
# bidsme.bidsify(97) - INFO 021-Axial_ASL_3D_2510/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A044', ses 'ses-03', 022-Perfusion_Weighted/0 (1 files)
# bidsme.bidsify(97) - INFO 022-Perfusion_Weighted/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A044', ses 'ses-03', 023-Axial_ASL_3D_3000/0 (1 files)
# bidsme.bidsify(97) - INFO 023-Axial_ASL_3D_3000/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A044', ses 'ses-03', 024-Perfusion_Weighted/0 (1 files)
# bidsme.bidsify(97) - INFO 024-Perfusion_Weighted/0: ignored modality
# bidsme.bidsify(344) - INFO sub-A046 (3/242): Scanning folder prepared/sub-A046/ses-02
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A046', ses 'ses-02', 000-20211025_111301MPRAGEGRAPPA2s002a1001.nii/0 (1 files)
# bidsme.bidsify(94) - ERROR 000-20211025_111301MPRAGEGRAPPA2s002a1001.nii/0: No compatible run found
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(386) in bidsify:
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(95) in coin:
# bidsme.exceptions.exceptions(51) - ERROR 1:ValueError: 000-20211025_111301MPRAGEGRAPPA2s002a1001.nii/0: No compatible run found
# bidsme.bidsify(389) - ERROR Error processing folder prepared/sub-A046/ses-02/MRI/000-20211025_111301MPRAGEGRAPPA2s002a1001.nii in file 20211025_111301MPRAGEGRAPPA2s002a1001.nii.gz
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A046', ses 'ses-02', 001-AA_R046_Resting.nii/0 (1 files)
# bidsme.bidsify(94) - ERROR 001-AA_R046_Resting.nii/0: No compatible run found
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(386) in bidsify:
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(95) in coin:
# bidsme.exceptions.exceptions(51) - ERROR 1:ValueError: 001-AA_R046_Resting.nii/0: No compatible run found
# bidsme.bidsify(389) - ERROR Error processing folder prepared/sub-A046/ses-02/MRI/001-AA_R046_Resting.nii in file AA_R046_Resting.nii.gz
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A046', ses 'ses-02', 002-AA_R046_Struct.nii/0 (1 files)
# bidsme.bidsify(94) - ERROR 002-AA_R046_Struct.nii/0: No compatible run found
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(386) in bidsify:
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(95) in coin:
# bidsme.exceptions.exceptions(51) - ERROR 1:ValueError: 002-AA_R046_Struct.nii/0: No compatible run found
# bidsme.bidsify(389) - ERROR Error processing folder prepared/sub-A046/ses-02/MRI/002-AA_R046_Struct.nii in file AA_R046_Struct.nii.gz
# bidsme.bidsify(344) - INFO sub-A079 (4/242): Scanning folder prepared/sub-A079/ses-03
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A079', ses 'ses-03', 000-AA_R079_L_Resting.nii/0 (1 files)
# bidsme.bidsify(94) - ERROR 000-AA_R079_L_Resting.nii/0: No compatible run found
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(386) in bidsify:
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(95) in coin:
# bidsme.exceptions.exceptions(51) - ERROR 1:ValueError: 000-AA_R079_L_Resting.nii/0: No compatible run found
# bidsme.bidsify(389) - ERROR Error processing folder prepared/sub-A079/ses-03/MRI/000-AA_R079_L_Resting.nii in file AA_R079_L_Resting.nii.gz
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A079', ses 'ses-03', 001-AA_R079_L_Struct.nii/0 (1 files)
# bidsme.bidsify(94) - ERROR 001-AA_R079_L_Struct.nii/0: No compatible run found
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(386) in bidsify:
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(95) in coin:
# bidsme.exceptions.exceptions(51) - ERROR 1:ValueError: 001-AA_R079_L_Struct.nii/0: No compatible run found
# bidsme.bidsify(389) - ERROR Error processing folder prepared/sub-A079/ses-03/MRI/001-AA_R079_L_Struct.nii in file AA_R079_L_Struct.nii.gz
# bidsme.bidsify(344) - INFO sub-A085 (5/242): Scanning folder prepared/sub-A085/ses-01
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A085', ses 'ses-01', 001-localizer/0 (3 files)
# bidsme.bidsify(97) - INFO 001-localizer/0: ignored modality
# bidsme.bidsify(97) - INFO 001-localizer/1: ignored modality
# bidsme.bidsify(97) - INFO 001-localizer/2: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A085', ses 'ses-01', 002-MPRAGE GRAPPA2/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A085', ses 'ses-01', 003-Axial T2-FLAIR/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A085', ses 'ses-01', 004-AXIAL_T2_STAR/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A085', ses 'ses-01', 005-Field_mapping/0 (1 files)
# bidsme.bidsify(97) - INFO 005-Field_mapping/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A085', ses 'ses-01', 006-MB_Resting_SBRef/0 (1 files)
# bidsme.bidsify(97) - INFO 006-MB_Resting_SBRef/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A085', ses 'ses-01', 007-MB_Resting/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A085', ses 'ses-01', 008-TestPhase_MB_SBRef/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A085', ses 'ses-01', 009-TestPhase_MB/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A085', ses 'ses-01', 010-ep2d_diff_30_iso/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 010-ep2d_diff_30_iso/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 010-ep2d_diff_30_iso/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A085', ses 'ses-01', 011-ep2d_diff_30_iso_ADC/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 011-ep2d_diff_30_iso_ADC/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 011-ep2d_diff_30_iso_ADC/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A085', ses 'ses-01', 012-ep2d_diff_30_iso_FA/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 012-ep2d_diff_30_iso_FA/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 012-ep2d_diff_30_iso_FA/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A085', ses 'ses-01', 013-ep2d_diff_30_iso_ColFA/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 013-ep2d_diff_30_iso_ColFA/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 013-ep2d_diff_30_iso_ColFA/0 missing bval file for diffusion recording
# bidsme.bidsify(344) - INFO sub-A085 (5/242): Scanning folder prepared/sub-A085/ses-02
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A085', ses 'ses-02', 001-localizer/0 (3 files)
# bidsme.bidsify(97) - INFO 001-localizer/0: ignored modality
# bidsme.bidsify(97) - INFO 001-localizer/1: ignored modality
# bidsme.bidsify(97) - INFO 001-localizer/2: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A085', ses 'ses-02', 002-MPRAGE GRAPPA2/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A085', ses 'ses-02', 003-Axial T2-FLAIR/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A085', ses 'ses-02', 004-AXIAL_T2_STAR/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A085', ses 'ses-02', 005-Field_mapping/0 (1 files)
# bidsme.bidsify(97) - INFO 005-Field_mapping/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A085', ses 'ses-02', 006-MB_Resting_SBRef/0 (1 files)
# bidsme.bidsify(97) - INFO 006-MB_Resting_SBRef/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A085', ses 'ses-02', 007-MB_Resting/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A085', ses 'ses-02', 008-TestPhase_MB_SBRef/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A085', ses 'ses-02', 009-TestPhase_MB/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A085', ses 'ses-02', 010-ep2d_diff_30_iso/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 010-ep2d_diff_30_iso/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 010-ep2d_diff_30_iso/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A085', ses 'ses-02', 011-ep2d_diff_30_iso_ADC/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 011-ep2d_diff_30_iso_ADC/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 011-ep2d_diff_30_iso_ADC/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A085', ses 'ses-02', 012-ep2d_diff_30_iso_FA/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 012-ep2d_diff_30_iso_FA/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 012-ep2d_diff_30_iso_FA/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A085', ses 'ses-02', 013-ep2d_diff_30_iso_ColFA/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 013-ep2d_diff_30_iso_ColFA/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 013-ep2d_diff_30_iso_ColFA/0 missing bval file for diffusion recording
# bidsme.bidsify(344) - INFO sub-A086 (6/242): Scanning folder prepared/sub-A086/ses-05
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A086', ses 'ses-05', 001-AAHead_Scout/0 (1 files)
# bidsme.bidsify(97) - INFO 001-AAHead_Scout/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A086', ses 'ses-05', 002-AAHead_Scout_MPR_sag/0 (4 files)
# bidsme.bidsify(97) - INFO 002-AAHead_Scout_MPR_sag/0: ignored modality
# bidsme.bidsify(97) - INFO 002-AAHead_Scout_MPR_sag/1: ignored modality
# bidsme.bidsify(97) - INFO 002-AAHead_Scout_MPR_sag/2: ignored modality
# bidsme.bidsify(97) - INFO 002-AAHead_Scout_MPR_sag/3: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A086', ses 'ses-05', 003-AAHead_Scout_MPR_cor/0 (3 files)
# bidsme.bidsify(97) - INFO 003-AAHead_Scout_MPR_cor/0: ignored modality
# bidsme.bidsify(97) - INFO 003-AAHead_Scout_MPR_cor/1: ignored modality
# bidsme.bidsify(97) - INFO 003-AAHead_Scout_MPR_cor/2: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A086', ses 'ses-05', 004-AAHead_Scout_MPR_tra/0 (3 files)
# bidsme.bidsify(97) - INFO 004-AAHead_Scout_MPR_tra/0: ignored modality
# bidsme.bidsify(97) - INFO 004-AAHead_Scout_MPR_tra/1: ignored modality
# bidsme.bidsify(97) - INFO 004-AAHead_Scout_MPR_tra/2: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A086', ses 'ses-05', 005-MPRage/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A086', ses 'ses-05', 006-Sagittal 3D FLAIR/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A086', ses 'ses-05', 007-MB_fMRI_resting_state/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A086', ses 'ses-05', 008-AXMB_DTI_AP/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 008-AXMB_DTI_AP/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 008-AXMB_DTI_AP/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A086', ses 'ses-05', 009-AXMB_DTI_PA/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 009-AXMB_DTI_PA/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 009-AXMB_DTI_PA/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A086', ses 'ses-05', 010-Sag_T2w_SPC/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A086', ses 'ses-05', 011-Axial 3D ME T2 GRE/0 (5 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A086', ses 'ses-05', 012-Axial 3D ME T2 GRE/0 (5 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A086', ses 'ses-05', 013-Axial ASL 3D 1000/0 (1 files)
# bidsme.bidsify(94) - ERROR 013-Axial ASL 3D 1000/0: No compatible run found
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(386) in bidsify:
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(95) in coin:
# bidsme.exceptions.exceptions(51) - ERROR 1:ValueError: 013-Axial ASL 3D 1000/0: No compatible run found
# bidsme.bidsify(389) - ERROR Error processing folder prepared/sub-A086/ses-05/MRI/013-Axial ASL 3D 1000 in file AA_4R086_L_13_Axial_ASL_3D_1000.nii.gz
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A086', ses 'ses-05', 014-Perfusion_Weighted/0 (1 files)
# bidsme.bidsify(94) - ERROR 014-Perfusion_Weighted/0: No compatible run found
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(386) in bidsify:
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(95) in coin:
# bidsme.exceptions.exceptions(51) - ERROR 1:ValueError: 014-Perfusion_Weighted/0: No compatible run found
# bidsme.bidsify(389) - ERROR Error processing folder prepared/sub-A086/ses-05/MRI/014-Perfusion_Weighted in file AA_4R086_L_14_Axial_ASL_3D_1000.nii.gz
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A086', ses 'ses-05', 015-Axial ASL 3D 1500/0 (1 files)
# bidsme.bidsify(94) - ERROR 015-Axial ASL 3D 1500/0: No compatible run found
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(386) in bidsify:
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(95) in coin:
# bidsme.exceptions.exceptions(51) - ERROR 1:ValueError: 015-Axial ASL 3D 1500/0: No compatible run found
# bidsme.bidsify(389) - ERROR Error processing folder prepared/sub-A086/ses-05/MRI/015-Axial ASL 3D 1500 in file AA_4R086_L_15_Axial_ASL_3D_1500.nii.gz
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A086', ses 'ses-05', 016-Perfusion_Weighted/0 (1 files)
# bidsme.bidsify(94) - ERROR 016-Perfusion_Weighted/0: No compatible run found
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(386) in bidsify:
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(95) in coin:
# bidsme.exceptions.exceptions(51) - ERROR 1:ValueError: 016-Perfusion_Weighted/0: No compatible run found
# bidsme.bidsify(389) - ERROR Error processing folder prepared/sub-A086/ses-05/MRI/016-Perfusion_Weighted in file AA_4R086_L_16_Axial_ASL_3D_1500.nii.gz
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A086', ses 'ses-05', 017-Axial ASL 3D 2000/0 (1 files)
# bidsme.bidsify(94) - ERROR 017-Axial ASL 3D 2000/0: No compatible run found
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(386) in bidsify:
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(95) in coin:
# bidsme.exceptions.exceptions(51) - ERROR 1:ValueError: 017-Axial ASL 3D 2000/0: No compatible run found
# bidsme.bidsify(389) - ERROR Error processing folder prepared/sub-A086/ses-05/MRI/017-Axial ASL 3D 2000 in file AA_4R086_L_17_Axial_ASL_3D_2000.nii.gz
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A086', ses 'ses-05', 018-Perfusion_Weighted/0 (1 files)
# bidsme.bidsify(94) - ERROR 018-Perfusion_Weighted/0: No compatible run found
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(386) in bidsify:
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(95) in coin:
# bidsme.exceptions.exceptions(51) - ERROR 1:ValueError: 018-Perfusion_Weighted/0: No compatible run found
# bidsme.bidsify(389) - ERROR Error processing folder prepared/sub-A086/ses-05/MRI/018-Perfusion_Weighted in file AA_4R086_L_18_Axial_ASL_3D_2000.nii.gz
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A086', ses 'ses-05', 019-Axial ASL 3D 2510/0 (1 files)
# bidsme.bidsify(94) - ERROR 019-Axial ASL 3D 2510/0: No compatible run found
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(386) in bidsify:
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(95) in coin:
# bidsme.exceptions.exceptions(51) - ERROR 1:ValueError: 019-Axial ASL 3D 2510/0: No compatible run found
# bidsme.bidsify(389) - ERROR Error processing folder prepared/sub-A086/ses-05/MRI/019-Axial ASL 3D 2510 in file AA_4R086_L_19_Axial_ASL_3D_2510.nii.gz
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A086', ses 'ses-05', 020-Perfusion_Weighted/0 (1 files)
# bidsme.bidsify(94) - ERROR 020-Perfusion_Weighted/0: No compatible run found
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(386) in bidsify:
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(95) in coin:
# bidsme.exceptions.exceptions(51) - ERROR 1:ValueError: 020-Perfusion_Weighted/0: No compatible run found
# bidsme.bidsify(389) - ERROR Error processing folder prepared/sub-A086/ses-05/MRI/020-Perfusion_Weighted in file AA_4R086_L_20_Axial_ASL_3D_2510.nii.gz
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A086', ses 'ses-05', 021-Axial ASL 3D 3000/0 (1 files)
# bidsme.bidsify(94) - ERROR 021-Axial ASL 3D 3000/0: No compatible run found
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(386) in bidsify:
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(95) in coin:
# bidsme.exceptions.exceptions(51) - ERROR 1:ValueError: 021-Axial ASL 3D 3000/0: No compatible run found
# bidsme.bidsify(389) - ERROR Error processing folder prepared/sub-A086/ses-05/MRI/021-Axial ASL 3D 3000 in file AA_4R086_L_21_Axial_ASL_3D_3000.nii.gz
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A086', ses 'ses-05', 022-Perfusion_Weighted/0 (1 files)
# bidsme.bidsify(94) - ERROR 022-Perfusion_Weighted/0: No compatible run found
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(386) in bidsify:
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(95) in coin:
# bidsme.exceptions.exceptions(51) - ERROR 1:ValueError: 022-Perfusion_Weighted/0: No compatible run found
# bidsme.bidsify(389) - ERROR Error processing folder prepared/sub-A086/ses-05/MRI/022-Perfusion_Weighted in file AA_4R086_L_22_Axial_ASL_3D_3000.nii.gz
# bidsme.bidsify(344) - INFO sub-A088 (7/242): Scanning folder prepared/sub-A088/ses-01
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A088', ses 'ses-01', 001-localizer/0 (3 files)
# bidsme.bidsify(97) - INFO 001-localizer/0: ignored modality
# bidsme.bidsify(97) - INFO 001-localizer/1: ignored modality
# bidsme.bidsify(97) - INFO 001-localizer/2: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A088', ses 'ses-01', 002-MPRAGE GRAPPA2/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A088', ses 'ses-01', 003-Axial T2-FLAIR/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A088', ses 'ses-01', 004-AXIAL_T2_STAR/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A088', ses 'ses-01', 005-Field_mapping/0 (1 files)
# bidsme.bidsify(97) - INFO 005-Field_mapping/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A088', ses 'ses-01', 006-MB_Resting_SBRef/0 (1 files)
# bidsme.bidsify(97) - INFO 006-MB_Resting_SBRef/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A088', ses 'ses-01', 007-MB_Resting/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A088', ses 'ses-01', 009-TestPhase_MB/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A088', ses 'ses-01', 010-ep2d_diff_30_iso/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 010-ep2d_diff_30_iso/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 010-ep2d_diff_30_iso/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A088', ses 'ses-01', 011-ep2d_diff_30_iso_ADC/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 011-ep2d_diff_30_iso_ADC/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 011-ep2d_diff_30_iso_ADC/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A088', ses 'ses-01', 012-ep2d_diff_30_iso_FA/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 012-ep2d_diff_30_iso_FA/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 012-ep2d_diff_30_iso_FA/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A088', ses 'ses-01', 013-ep2d_diff_30_iso_ColFA/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 013-ep2d_diff_30_iso_ColFA/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 013-ep2d_diff_30_iso_ColFA/0 missing bval file for diffusion recording
# bidsme.bidsify(344) - INFO sub-A091 (8/242): Scanning folder prepared/sub-A091/ses-01
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A091', ses 'ses-01', 001-localizer/0 (3 files)
# bidsme.bidsify(97) - INFO 001-localizer/0: ignored modality
# bidsme.bidsify(97) - INFO 001-localizer/1: ignored modality
# bidsme.bidsify(97) - INFO 001-localizer/2: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A091', ses 'ses-01', 002-T1 MPRage 32Channel_NoGrappa/0 (1 files)
# bidsme.bidsify(94) - ERROR 002-T1 MPRage 32Channel_NoGrappa/0: No compatible run found
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(386) in bidsify:
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(95) in coin:
# bidsme.exceptions.exceptions(51) - ERROR 1:ValueError: 002-T1 MPRage 32Channel_NoGrappa/0: No compatible run found
# bidsme.bidsify(389) - ERROR Error processing folder prepared/sub-A091/ses-01/MRI/002-T1 MPRage 32Channel_NoGrappa in file AA_091_2_T1_MPRage_32Channel_NoGrappa.nii.gz
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A091', ses 'ses-01', 003-T1 MPRage 32Channel_Grappa/0 (1 files)
# bidsme.bidsify(94) - ERROR 003-T1 MPRage 32Channel_Grappa/0: No compatible run found
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(386) in bidsify:
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(95) in coin:
# bidsme.exceptions.exceptions(51) - ERROR 1:ValueError: 003-T1 MPRage 32Channel_Grappa/0: No compatible run found
# bidsme.bidsify(389) - ERROR Error processing folder prepared/sub-A091/ses-01/MRI/003-T1 MPRage 32Channel_Grappa in file AA_091_3_T1_MPRage_32Channel_Grappa.nii.gz
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A091', ses 'ses-01', 004-gre_field_mapping/0 (2 files)
# bidsme.bidsify(94) - ERROR 004-gre_field_mapping/0: No compatible run found
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(386) in bidsify:
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(95) in coin:
# bidsme.exceptions.exceptions(51) - ERROR 1:ValueError: 004-gre_field_mapping/0: No compatible run found
# bidsme.bidsify(389) - ERROR Error processing folder prepared/sub-A091/ses-01/MRI/004-gre_field_mapping in file AA_091_4_gre_field_mapping_e1.nii.gz
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A091', ses 'ses-01', 005-gre_field_mapping/0 (1 files)
# bidsme.bidsify(94) - ERROR 005-gre_field_mapping/0: No compatible run found
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(386) in bidsify:
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(95) in coin:
# bidsme.exceptions.exceptions(51) - ERROR 1:ValueError: 005-gre_field_mapping/0: No compatible run found
# bidsme.bidsify(389) - ERROR Error processing folder prepared/sub-A091/ses-01/MRI/005-gre_field_mapping in file AA_091_5_gre_field_mapping_e2_ph.nii.gz
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A091', ses 'ses-01', 006-MB_Resting_SBRef/0 (1 files)
# bidsme.bidsify(97) - INFO 006-MB_Resting_SBRef/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A091', ses 'ses-01', 007-MB_Resting/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A091', ses 'ses-01', 008-TestPhase_MB_SBRef/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A091', ses 'ses-01', 009-TestPhase_MB/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A091', ses 'ses-01', 010-ep2d_diff_30_iso/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 010-ep2d_diff_30_iso/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 010-ep2d_diff_30_iso/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A091', ses 'ses-01', 011-ep2d_diff_30_iso_ADC/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 011-ep2d_diff_30_iso_ADC/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 011-ep2d_diff_30_iso_ADC/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A091', ses 'ses-01', 012-ep2d_diff_30_iso_FA/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 012-ep2d_diff_30_iso_FA/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 012-ep2d_diff_30_iso_FA/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A091', ses 'ses-01', 013-ep2d_diff_30_iso_ColFA/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 013-ep2d_diff_30_iso_ColFA/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 013-ep2d_diff_30_iso_ColFA/0 missing bval file for diffusion recording
# bidsme.bidsify(344) - INFO sub-A091 (8/242): Scanning folder prepared/sub-A091/ses-03
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A091', ses 'ses-03', 000-AA_R091_L_Resting.nii/0 (1 files)
# bidsme.bidsify(94) - ERROR 000-AA_R091_L_Resting.nii/0: No compatible run found
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(386) in bidsify:
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(95) in coin:
# bidsme.exceptions.exceptions(51) - ERROR 1:ValueError: 000-AA_R091_L_Resting.nii/0: No compatible run found
# bidsme.bidsify(389) - ERROR Error processing folder prepared/sub-A091/ses-03/MRI/000-AA_R091_L_Resting.nii in file AA_R091_L_Resting.nii.gz
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A091', ses 'ses-03', 001-AA_R091_L_Struct.nii/0 (1 files)
# bidsme.bidsify(94) - ERROR 001-AA_R091_L_Struct.nii/0: No compatible run found
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(386) in bidsify:
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(95) in coin:
# bidsme.exceptions.exceptions(51) - ERROR 1:ValueError: 001-AA_R091_L_Struct.nii/0: No compatible run found
# bidsme.bidsify(389) - ERROR Error processing folder prepared/sub-A091/ses-03/MRI/001-AA_R091_L_Struct.nii in file AA_R091_L_Struct.nii.gz
# bidsme.bidsify(344) - INFO sub-A094 (9/242): Scanning folder prepared/sub-A094/ses-01
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A094', ses 'ses-01', 001-localizer/0 (3 files)
# bidsme.bidsify(97) - INFO 001-localizer/0: ignored modality
# bidsme.bidsify(97) - INFO 001-localizer/1: ignored modality
# bidsme.bidsify(97) - INFO 001-localizer/2: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A094', ses 'ses-01', 002-MPRAGE GRAPPA2/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A094', ses 'ses-01', 003-Axial T2-FLAIR/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A094', ses 'ses-01', 004-AXIAL_T2_STAR/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A094', ses 'ses-01', 005-Field_mapping/0 (1 files)
# bidsme.bidsify(97) - INFO 005-Field_mapping/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A094', ses 'ses-01', 006-MB_Resting_SBRef/0 (1 files)
# bidsme.bidsify(97) - INFO 006-MB_Resting_SBRef/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A094', ses 'ses-01', 007-MB_Resting/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A094', ses 'ses-01', 008-TestPhase_MB_SBRef/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A094', ses 'ses-01', 009-TestPhase_MB/0 (1 files)
# bidsme.bidsify(344) - INFO sub-A096 (10/242): Scanning folder prepared/sub-A096/ses-01
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A096', ses 'ses-01', 001-localizer/0 (3 files)
# bidsme.bidsify(97) - INFO 001-localizer/0: ignored modality
# bidsme.bidsify(97) - INFO 001-localizer/1: ignored modality
# bidsme.bidsify(97) - INFO 001-localizer/2: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A096', ses 'ses-01', 002-MPRAGE GRAPPA2/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A096', ses 'ses-01', 003-Axial T2-FLAIR/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A096', ses 'ses-01', 004-AXIAL_T2_STAR/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A096', ses 'ses-01', 005-Field_mapping/0 (1 files)
# bidsme.bidsify(97) - INFO 005-Field_mapping/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A096', ses 'ses-01', 006-MB_Resting_SBRef/0 (1 files)
# bidsme.bidsify(97) - INFO 006-MB_Resting_SBRef/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A096', ses 'ses-01', 007-MB_Resting/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A096', ses 'ses-01', 008-TestPhase_MB_SBRef/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A096', ses 'ses-01', 009-TestPhase_MB/0 (1 files)
# bidsme.bidsify(344) - INFO sub-A100 (11/242): Scanning folder prepared/sub-A100/ses-01
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A100', ses 'ses-01', 001-localizer/0 (3 files)
# bidsme.bidsify(97) - INFO 001-localizer/0: ignored modality
# bidsme.bidsify(97) - INFO 001-localizer/1: ignored modality
# bidsme.bidsify(97) - INFO 001-localizer/2: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A100', ses 'ses-01', 002-localizer/0 (3 files)
# bidsme.bidsify(97) - INFO 002-localizer/0: ignored modality
# bidsme.bidsify(97) - INFO 002-localizer/1: ignored modality
# bidsme.bidsify(97) - INFO 002-localizer/2: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A100', ses 'ses-01', 003-MPRAGE GRAPPA2/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A100', ses 'ses-01', 004-Axial T2-FLAIR/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A100', ses 'ses-01', 005-AXIAL_T2_STAR/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A100', ses 'ses-01', 006-Field_mapping/0 (1 files)
# bidsme.bidsify(97) - INFO 006-Field_mapping/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A100', ses 'ses-01', 007-MB_Resting_SBRef/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A100', ses 'ses-01', 008-MB_Resting/0 (1 files)
# bidsme.bidsify(94) - ERROR 008-MB_Resting/0: No compatible run found
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(386) in bidsify:
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(95) in coin:
# bidsme.exceptions.exceptions(51) - ERROR 1:ValueError: 008-MB_Resting/0: No compatible run found
# bidsme.bidsify(389) - ERROR Error processing folder prepared/sub-A100/ses-01/MRI/008-MB_Resting in file AA_100_8_MB_Resting.nii.gz
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A100', ses 'ses-01', 009-TestPhase_MB_SBRef/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A100', ses 'ses-01', 010-TestPhase_MB/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A100', ses 'ses-01', 011-ep2d_diff_30_iso/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 011-ep2d_diff_30_iso/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 011-ep2d_diff_30_iso/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A100', ses 'ses-01', 012-ep2d_diff_30_iso_ADC/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 012-ep2d_diff_30_iso_ADC/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 012-ep2d_diff_30_iso_ADC/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A100', ses 'ses-01', 013-ep2d_diff_30_iso_FA/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 013-ep2d_diff_30_iso_FA/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 013-ep2d_diff_30_iso_FA/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A100', ses 'ses-01', 014-ep2d_diff_30_iso_ColFA/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 014-ep2d_diff_30_iso_ColFA/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 014-ep2d_diff_30_iso_ColFA/0 missing bval file for diffusion recording
# bidsme.bidsify(344) - INFO sub-A101 (12/242): Scanning folder prepared/sub-A101/ses-01
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A101', ses 'ses-01', 001-localizer/0 (3 files)
# bidsme.bidsify(97) - INFO 001-localizer/0: ignored modality
# bidsme.bidsify(97) - INFO 001-localizer/1: ignored modality
# bidsme.bidsify(97) - INFO 001-localizer/2: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A101', ses 'ses-01', 002-MPRAGE GRAPPA2/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A101', ses 'ses-01', 003-Axial T2-FLAIR/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A101', ses 'ses-01', 004-AXIAL_T2_STAR/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A101', ses 'ses-01', 005-Field_mapping/0 (1 files)
# bidsme.bidsify(97) - INFO 005-Field_mapping/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A101', ses 'ses-01', 006-MB_Resting_SBRef/0 (1 files)
# bidsme.bidsify(97) - INFO 006-MB_Resting_SBRef/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A101', ses 'ses-01', 007-MB_Resting/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A101', ses 'ses-01', 008-TestPhase_MB_SBRef/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A101', ses 'ses-01', 009-TestPhase_MB/0 (1 files)
# bidsme.bidsify(344) - INFO sub-A103 (13/242): Scanning folder prepared/sub-A103/ses-01
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A103', ses 'ses-01', 001-localizer/0 (3 files)
# bidsme.bidsify(97) - INFO 001-localizer/0: ignored modality
# bidsme.bidsify(97) - INFO 001-localizer/1: ignored modality
# bidsme.bidsify(97) - INFO 001-localizer/2: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A103', ses 'ses-01', 002-MPRAGE GRAPPA2/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A103', ses 'ses-01', 003-Axial T2-FLAIR/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A103', ses 'ses-01', 004-AXIAL_T2_STAR/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A103', ses 'ses-01', 005-Field_mapping/0 (1 files)
# bidsme.bidsify(97) - INFO 005-Field_mapping/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A103', ses 'ses-01', 006-MB_Resting_SBRef/0 (1 files)
# bidsme.bidsify(97) - INFO 006-MB_Resting_SBRef/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A103', ses 'ses-01', 007-MB_Resting/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A103', ses 'ses-01', 008-TestPhase_MB_SBRef/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A103', ses 'ses-01', 009-TestPhase_MB/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A103', ses 'ses-01', 010-ep2d_diff_30_iso/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 010-ep2d_diff_30_iso/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 010-ep2d_diff_30_iso/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A103', ses 'ses-01', 011-ep2d_diff_30_iso_ADC/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 011-ep2d_diff_30_iso_ADC/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 011-ep2d_diff_30_iso_ADC/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A103', ses 'ses-01', 012-ep2d_diff_30_iso_FA/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 012-ep2d_diff_30_iso_FA/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 012-ep2d_diff_30_iso_FA/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A103', ses 'ses-01', 013-ep2d_diff_30_iso_ColFA/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 013-ep2d_diff_30_iso_ColFA/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 013-ep2d_diff_30_iso_ColFA/0 missing bval file for diffusion recording
# bidsme.bidsify(344) - INFO sub-A103 (13/242): Scanning folder prepared/sub-A103/ses-03
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A103', ses 'ses-03', 000-AA_R103_L_Resting.nii/0 (1 files)
# bidsme.bidsify(94) - ERROR 000-AA_R103_L_Resting.nii/0: No compatible run found
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(386) in bidsify:
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(95) in coin:
# bidsme.exceptions.exceptions(51) - ERROR 1:ValueError: 000-AA_R103_L_Resting.nii/0: No compatible run found
# bidsme.bidsify(389) - ERROR Error processing folder prepared/sub-A103/ses-03/MRI/000-AA_R103_L_Resting.nii in file AA_R103_L_Resting.nii.gz
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A103', ses 'ses-03', 001-AA_R103_L_Struct.nii/0 (1 files)
# bidsme.bidsify(94) - ERROR 001-AA_R103_L_Struct.nii/0: No compatible run found
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(386) in bidsify:
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(95) in coin:
# bidsme.exceptions.exceptions(51) - ERROR 1:ValueError: 001-AA_R103_L_Struct.nii/0: No compatible run found
# bidsme.bidsify(389) - ERROR Error processing folder prepared/sub-A103/ses-03/MRI/001-AA_R103_L_Struct.nii in file AA_R103_L_Struct.nii.gz
# bidsme.bidsify(344) - INFO sub-A104 (14/242): Scanning folder prepared/sub-A104/ses-01
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A104', ses 'ses-01', 001-localizer/0 (3 files)
# bidsme.bidsify(97) - INFO 001-localizer/0: ignored modality
# bidsme.bidsify(97) - INFO 001-localizer/1: ignored modality
# bidsme.bidsify(97) - INFO 001-localizer/2: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A104', ses 'ses-01', 002-MPRAGE GRAPPA2/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A104', ses 'ses-01', 003-Axial T2-FLAIR/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A104', ses 'ses-01', 004-AXIAL_T2_STAR/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A104', ses 'ses-01', 005-Field_mapping/0 (1 files)
# bidsme.bidsify(97) - INFO 005-Field_mapping/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A104', ses 'ses-01', 006-MB_Resting_SBRef/0 (1 files)
# bidsme.bidsify(97) - INFO 006-MB_Resting_SBRef/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A104', ses 'ses-01', 007-MB_Resting/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A104', ses 'ses-01', 008-TestPhase_MB_SBRef/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-A104', ses 'ses-01', 009-TestPhase_MB/0 (1 files)
# ...
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L045', ses 'ses-03', 016-Perfusion_Weighted/0 (1 files)
# bidsme.bidsify(94) - ERROR 016-Perfusion_Weighted/0: No compatible run found
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(386) in bidsify:
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(95) in coin:
# bidsme.exceptions.exceptions(51) - ERROR 1:ValueError: 016-Perfusion_Weighted/0: No compatible run found
# bidsme.bidsify(389) - ERROR Error processing folder prepared/sub-L045/ses-03/MRI/016-Perfusion_Weighted in file AAL_3R045_16_Axial_ASL_3D_1000.nii.gz
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L045', ses 'ses-03', 017-Axial ASL 3D 1500/0 (1 files)
# bidsme.bidsify(94) - ERROR 017-Axial ASL 3D 1500/0: No compatible run found
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(386) in bidsify:
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(95) in coin:
# bidsme.exceptions.exceptions(51) - ERROR 1:ValueError: 017-Axial ASL 3D 1500/0: No compatible run found
# bidsme.bidsify(389) - ERROR Error processing folder prepared/sub-L045/ses-03/MRI/017-Axial ASL 3D 1500 in file AAL_3R045_17_Axial_ASL_3D_1500.nii.gz
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L045', ses 'ses-03', 018-Perfusion_Weighted/0 (1 files)
# bidsme.bidsify(94) - ERROR 018-Perfusion_Weighted/0: No compatible run found
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(386) in bidsify:
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(95) in coin:
# bidsme.exceptions.exceptions(51) - ERROR 1:ValueError: 018-Perfusion_Weighted/0: No compatible run found
# bidsme.bidsify(389) - ERROR Error processing folder prepared/sub-L045/ses-03/MRI/018-Perfusion_Weighted in file AAL_3R045_18_Axial_ASL_3D_1500.nii.gz
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L045', ses 'ses-03', 019-Axial ASL 3D 2000/0 (1 files)
# bidsme.bidsify(94) - ERROR 019-Axial ASL 3D 2000/0: No compatible run found
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(386) in bidsify:
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(95) in coin:
# bidsme.exceptions.exceptions(51) - ERROR 1:ValueError: 019-Axial ASL 3D 2000/0: No compatible run found
# bidsme.bidsify(389) - ERROR Error processing folder prepared/sub-L045/ses-03/MRI/019-Axial ASL 3D 2000 in file AAL_3R045_19_Axial_ASL_3D_2000.nii.gz
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L045', ses 'ses-03', 020-Perfusion_Weighted/0 (1 files)
# bidsme.bidsify(94) - ERROR 020-Perfusion_Weighted/0: No compatible run found
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(386) in bidsify:
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(95) in coin:
# bidsme.exceptions.exceptions(51) - ERROR 1:ValueError: 020-Perfusion_Weighted/0: No compatible run found
# bidsme.bidsify(389) - ERROR Error processing folder prepared/sub-L045/ses-03/MRI/020-Perfusion_Weighted in file AAL_3R045_20_Axial_ASL_3D_2000.nii.gz
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L045', ses 'ses-03', 021-Axial ASL 3D 2510/0 (1 files)
# bidsme.bidsify(94) - ERROR 021-Axial ASL 3D 2510/0: No compatible run found
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(386) in bidsify:
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(95) in coin:
# bidsme.exceptions.exceptions(51) - ERROR 1:ValueError: 021-Axial ASL 3D 2510/0: No compatible run found
# bidsme.bidsify(389) - ERROR Error processing folder prepared/sub-L045/ses-03/MRI/021-Axial ASL 3D 2510 in file AAL_3R045_21_Axial_ASL_3D_2510.nii.gz
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L045', ses 'ses-03', 022-Perfusion_Weighted/0 (1 files)
# bidsme.bidsify(94) - ERROR 022-Perfusion_Weighted/0: No compatible run found
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(386) in bidsify:
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(95) in coin:
# bidsme.exceptions.exceptions(51) - ERROR 1:ValueError: 022-Perfusion_Weighted/0: No compatible run found
# bidsme.bidsify(389) - ERROR Error processing folder prepared/sub-L045/ses-03/MRI/022-Perfusion_Weighted in file AAL_3R045_22_Axial_ASL_3D_2510.nii.gz
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L045', ses 'ses-03', 023-Axial ASL 3D 3000/0 (1 files)
# bidsme.bidsify(94) - ERROR 023-Axial ASL 3D 3000/0: No compatible run found
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(386) in bidsify:
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(95) in coin:
# bidsme.exceptions.exceptions(51) - ERROR 1:ValueError: 023-Axial ASL 3D 3000/0: No compatible run found
# bidsme.bidsify(389) - ERROR Error processing folder prepared/sub-L045/ses-03/MRI/023-Axial ASL 3D 3000 in file AAL_3R045_23_Axial_ASL_3D_3000.nii.gz
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L045', ses 'ses-03', 024-Perfusion_Weighted/0 (1 files)
# bidsme.bidsify(94) - ERROR 024-Perfusion_Weighted/0: No compatible run found
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(386) in bidsify:
# bidsme.exceptions.exceptions(49) - ERROR /home/jlmojicaperez/miniconda3/envs/bidsme-env/lib/python3.10/site-packages/bidsme/bidsify.py(95) in coin:
# bidsme.exceptions.exceptions(51) - ERROR 1:ValueError: 024-Perfusion_Weighted/0: No compatible run found
# bidsme.bidsify(389) - ERROR Error processing folder prepared/sub-L045/ses-03/MRI/024-Perfusion_Weighted in file AAL_3R045_24_Axial_ASL_3D_3000.nii.gz
# bidsme.bidsify(344) - INFO sub-L052 (239/242): Scanning folder prepared/sub-L052/ses-01
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L052', ses 'ses-01', 001-localizer/0 (3 files)
# bidsme.bidsify(97) - INFO 001-localizer/0: ignored modality
# bidsme.bidsify(97) - INFO 001-localizer/1: ignored modality
# bidsme.bidsify(97) - INFO 001-localizer/2: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L052', ses 'ses-01', 002-MPRAGE GRAPPA2/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L052', ses 'ses-01', 003-Axial T2-FLAIR/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L052', ses 'ses-01', 004-AXIAL_T2_STAR/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L052', ses 'ses-01', 005-Field_mapping/0 (1 files)
# bidsme.bidsify(97) - INFO 005-Field_mapping/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L052', ses 'ses-01', 006-MB_Resting_SBRef/0 (1 files)
# bidsme.bidsify(97) - INFO 006-MB_Resting_SBRef/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L052', ses 'ses-01', 007-MB_Resting/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L052', ses 'ses-01', 008-ep2d_diff_30_iso/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 008-ep2d_diff_30_iso/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 008-ep2d_diff_30_iso/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L052', ses 'ses-01', 009-ep2d_diff_30_iso_ADC/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 009-ep2d_diff_30_iso_ADC/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 009-ep2d_diff_30_iso_ADC/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L052', ses 'ses-01', 010-ep2d_diff_30_iso_FA/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 010-ep2d_diff_30_iso_FA/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 010-ep2d_diff_30_iso_FA/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L052', ses 'ses-01', 011-ep2d_diff_30_iso_ColFA/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 011-ep2d_diff_30_iso_ColFA/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 011-ep2d_diff_30_iso_ColFA/0 missing bval file for diffusion recording
# bidsme.bidsify(344) - INFO sub-L054 (240/242): Scanning folder prepared/sub-L054/ses-01
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L054', ses 'ses-01', 001-localizer/0 (3 files)
# bidsme.bidsify(97) - INFO 001-localizer/0: ignored modality
# bidsme.bidsify(97) - INFO 001-localizer/1: ignored modality
# bidsme.bidsify(97) - INFO 001-localizer/2: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L054', ses 'ses-01', 002-MPRAGE GRAPPA2/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L054', ses 'ses-01', 003-Axial T2-FLAIR/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L054', ses 'ses-01', 004-AXIAL_T2_STAR/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L054', ses 'ses-01', 005-Field_mapping/0 (1 files)
# bidsme.bidsify(97) - INFO 005-Field_mapping/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L054', ses 'ses-01', 006-MB_Resting_SBRef/0 (1 files)
# bidsme.bidsify(97) - INFO 006-MB_Resting_SBRef/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L054', ses 'ses-01', 007-MB_Resting/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L054', ses 'ses-01', 008-ep2d_diff_30_iso/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 008-ep2d_diff_30_iso/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 008-ep2d_diff_30_iso/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L054', ses 'ses-01', 009-ep2d_diff_30_iso_ADC/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 009-ep2d_diff_30_iso_ADC/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 009-ep2d_diff_30_iso_ADC/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L054', ses 'ses-01', 010-ep2d_diff_30_iso_FA/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 010-ep2d_diff_30_iso_FA/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 010-ep2d_diff_30_iso_FA/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L054', ses 'ses-01', 011-ep2d_diff_30_iso_ColFA/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 011-ep2d_diff_30_iso_ColFA/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 011-ep2d_diff_30_iso_ColFA/0 missing bval file for diffusion recording
# bidsme.bidsify(344) - INFO sub-L103 (241/242): Scanning folder prepared/sub-L103/ses-02
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L103', ses 'ses-02', 001-localizer/0 (3 files)
# bidsme.bidsify(97) - INFO 001-localizer/0: ignored modality
# bidsme.bidsify(97) - INFO 001-localizer/1: ignored modality
# bidsme.bidsify(97) - INFO 001-localizer/2: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L103', ses 'ses-02', 002-MPRAGE GRAPPA2/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L103', ses 'ses-02', 003-Axial T2-FLAIR/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L103', ses 'ses-02', 004-AXIAL_T2_STAR/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L103', ses 'ses-02', 005-Field_mapping/0 (1 files)
# bidsme.bidsify(97) - INFO 005-Field_mapping/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L103', ses 'ses-02', 006-MB_Resting_SBRef/0 (1 files)
# bidsme.bidsify(97) - INFO 006-MB_Resting_SBRef/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L103', ses 'ses-02', 007-MB_Resting/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L103', ses 'ses-02', 008-ep2d_diff_30_iso/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 008-ep2d_diff_30_iso/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 008-ep2d_diff_30_iso/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L103', ses 'ses-02', 009-ep2d_diff_30_iso_ADC/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 009-ep2d_diff_30_iso_ADC/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 009-ep2d_diff_30_iso_ADC/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L103', ses 'ses-02', 010-ep2d_diff_30_iso_FA/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 010-ep2d_diff_30_iso_FA/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 010-ep2d_diff_30_iso_FA/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L103', ses 'ses-02', 011-ep2d_diff_30_iso_ColFA/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 011-ep2d_diff_30_iso_ColFA/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 011-ep2d_diff_30_iso_ColFA/0 missing bval file for diffusion recording
# bidsme.bidsify(344) - INFO sub-L225 (242/242): Scanning folder prepared/sub-L225/ses-02
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L225', ses 'ses-02', 001-localizer/0 (3 files)
# bidsme.bidsify(97) - INFO 001-localizer/0: ignored modality
# bidsme.bidsify(97) - INFO 001-localizer/1: ignored modality
# bidsme.bidsify(97) - INFO 001-localizer/2: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L225', ses 'ses-02', 002-MPRAGE GRAPPA2/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L225', ses 'ses-02', 003-Axial T2-FLAIR/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L225', ses 'ses-02', 004-AXIAL_T2_STAR/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L225', ses 'ses-02', 005-Field_mapping/0 (1 files)
# bidsme.bidsify(97) - INFO 005-Field_mapping/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L225', ses 'ses-02', 006-MB_Resting_SBRef/0 (1 files)
# bidsme.bidsify(97) - INFO 006-MB_Resting_SBRef/0: ignored modality
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L225', ses 'ses-02', 007-MB_Resting/0 (1 files)
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L225', ses 'ses-02', 008-ep2d_diff_30_iso/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 008-ep2d_diff_30_iso/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 008-ep2d_diff_30_iso/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L225', ses 'ses-02', 009-ep2d_diff_30_iso_ADC/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 009-ep2d_diff_30_iso_ADC/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 009-ep2d_diff_30_iso_ADC/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L225', ses 'ses-02', 010-ep2d_diff_30_iso_FA/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 010-ep2d_diff_30_iso_FA/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 010-ep2d_diff_30_iso_FA/0 missing bval file for diffusion recording
# bidsme.bidsify(70) - INFO Processing: sub 'sub-L225', ses 'ses-02', 011-ep2d_diff_30_iso_ColFA/0 (1 files)
# bidsme.Modules.MRI.MRI(76) - WARNING 011-ep2d_diff_30_iso_ColFA/0 missing bvec file for diffusion recording
# bidsme.Modules.MRI.MRI(83) - WARNING 011-ep2d_diff_30_iso_ColFA/0 missing bval file for diffusion recording

# %%
def bidsify_bval_bvec(subject, session, reorganize_dir, bidsified_dir):

    reorganized_session_path = os.path.join(reorganize_dir, subject, session)

    for file in os.listdir(reorganized_session_path):
        rename = None
        if file.endswith("bval") or file.endswith("bvec"):
            if file.endswith("AP.bval"):
                rename = f"{subject}_{session}_dir-AP_dwi.bval"
            elif file.endswith("PA.bval"):
                rename = f"{subject}_{session}_dir-PA_dwi.bval"
            elif file.endswith("AP.bvec"):
                rename = f"{subject}_{session}_dir-AP_dwi.bvec"
            elif file.endswith("PA.bvec"):
                rename = f"{subject}_{session}_dir-PA_dwi.bvec"
            elif file.endswith("iso.bval"):
                rename = f"{subject}_{session}_acq-iso_dwi.bval"
            elif file.endswith("iso.bvec"):
                rename = f"{subject}_{session}_acq-iso_dwi.bvec"
            elif file.endswith("isoa.bval"):
                rename = f"{subject}_{session}_acq-iso_dwi.bval"
            elif file.endswith("isoa.bvec"):
                rename = f"{subject}_{session}_acq-iso_dwi.bvec"

            source_path = os.path.join(reorganized_session_path, file)
            destination_path = os.path.join(bidsified_dir, subject, session, "dwi", rename)
            now = datetime.datetime.now()
            log_entry = {"subject": subject, 
                        "session": session, 
                        "filename": file,
                        "rename": rename,
                        "source_path": source_path,
                        "destination_path": destination_path,
                        "bidsification_date": now.date(),
                        "bidsification_time": now.time(),
                        }
            
            try:
                shutil.move(source_path, destination_path)
                log_entry["status"] = "success"
                log_entry["error"] = None

            except Exception as error:
                log_entry["status"] = "fail"
                log_entry["error"] = error

            return log_entry

# %%
bidsify_bval_bvec_args = []
for dirpath, dirnames, filenames in os.walk(bidsified_dir):
    if dirpath.endswith("dwi"):
        split_path = dirpath.split("/")
        session = split_path[-2]
        subject = split_path[-3]
        bidsify_bval_bvec_args.append((subject, session, reorganize_dir, bidsified_dir))


bidsify_bval_bvec_log = []
with Pool(number_of_subprocesses) as p:
    bidsify_bval_bvec_log = p.starmap(bidsify_bval_bvec, bidsify_bval_bvec_args)

bidsify_bval_bvec_log = pd.DataFrame(bidsify_bval_bvec_log)
bidsify_bval_bvec_log
# Out:
#       subject session                           filename  \
# 0    sub-C278  ses-01   EX045_COV278_11_AXMB_DTI_PA.bval
# 1    sub-C248  ses-01          COV248_8_AXMB_DTI_AP.bvec
# 2    sub-C327  ses-01         COV327_11_AXMB_DTI_PA.bval
# 3    sub-A085  ses-02   AA_R085_10_ep2d_diff_30_iso.bval
# 4    sub-A085  ses-01    AA_085_10_ep2d_diff_30_iso.bvec
# ..        ...     ...                                ...
# 244  sub-C177  ses-01          COV177_8_AXMB_DTI_AP.bvec
# 245  sub-C117  ses-01     Cov117_8_ep2d_diff_30_iso.bval
# 246  sub-A382  ses-01  AA_382_Q_10_ep2d_diff_30_iso.bval
# 247  sub-C213  ses-01          COV213_8_AXMB_DTI_AP.bval
# 248  sub-A267  ses-05      AA_4R267_L_9_AXMB_DTI_PA.bvec
#
#                                rename  \
# 0     sub-C278_ses-01_dir-PA_dwi.bval
# 1     sub-C248_ses-01_dir-AP_dwi.bvec
# 2     sub-C327_ses-01_dir-PA_dwi.bval
# 3    sub-A085_ses-02_acq-iso_dwi.bval
# 4    sub-A085_ses-01_acq-iso_dwi.bvec
# ..                                ...
# 244   sub-C177_ses-01_dir-AP_dwi.bvec
# 245  sub-C117_ses-01_acq-iso_dwi.bval
# 246  sub-A382_ses-01_acq-iso_dwi.bval
# 247   sub-C213_ses-01_dir-AP_dwi.bval
# 248   sub-A267_ses-05_dir-PA_dwi.bvec
#
#                                            source_path  \
# 0    reorganized/sub-C278/ses-01/EX045_COV278_11_AX...
# 1    reorganized/sub-C248/ses-01/COV248_8_AXMB_DTI_...
# 2    reorganized/sub-C327/ses-01/COV327_11_AXMB_DTI...
# 3    reorganized/sub-A085/ses-02/AA_R085_10_ep2d_di...
# 4    reorganized/sub-A085/ses-01/AA_085_10_ep2d_dif...
# ..                                                 ...
# 244  reorganized/sub-C177/ses-01/COV177_8_AXMB_DTI_...
# 245  reorganized/sub-C117/ses-01/Cov117_8_ep2d_diff...
# 246  reorganized/sub-A382/ses-01/AA_382_Q_10_ep2d_d...
# 247  reorganized/sub-C213/ses-01/COV213_8_AXMB_DTI_...
# 248  reorganized/sub-A267/ses-05/AA_4R267_L_9_AXMB_...
#
#                                       destination_path bidsification_date  \
# 0    bidsified/sub-C278/ses-01/dwi/sub-C278_ses-01_...         2025-01-13
# 1    bidsified/sub-C248/ses-01/dwi/sub-C248_ses-01_...         2025-01-13
# 2    bidsified/sub-C327/ses-01/dwi/sub-C327_ses-01_...         2025-01-13
# 3    bidsified/sub-A085/ses-02/dwi/sub-A085_ses-02_...         2025-01-13
# 4    bidsified/sub-A085/ses-01/dwi/sub-A085_ses-01_...         2025-01-13
# ..                                                 ...                ...
# 244  bidsified/sub-C177/ses-01/dwi/sub-C177_ses-01_...         2025-01-13
# 245  bidsified/sub-C117/ses-01/dwi/sub-C117_ses-01_...         2025-01-13
# 246  bidsified/sub-A382/ses-01/dwi/sub-A382_ses-01_...         2025-01-13
# 247  bidsified/sub-C213/ses-01/dwi/sub-C213_ses-01_...         2025-01-13
# 248  bidsified/sub-A267/ses-05/dwi/sub-A267_ses-05_...         2025-01-13
#
#     bidsification_time   status error
# 0      17:37:38.961158  success  None
# 1      17:37:38.961249  success  None
# 2      17:37:38.961349  success  None
# 3      17:37:38.961453  success  None
# 4      17:37:38.961568  success  None
# ..                 ...      ...   ...
# 244    17:37:38.973740  success  None
# 245    17:37:38.973960  success  None
# 246    17:37:38.973826  success  None
# 247    17:37:38.973851  success  None
# 248    17:37:38.973888  success  None
#
# [249 rows x 10 columns]

# %%
bidsify_bval_bvec_log.to_csv(bidsify_bval_bvec_log_path, index=False)
